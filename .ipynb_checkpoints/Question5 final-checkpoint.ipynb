# %%
import pandas as pd
import numpy as np

# %%
# Reading C-18 POPULATION BY BILINGUALISM, TRILINGUALISM, AGE AND SEX
df = pd.read_excel('DDW-C18-0000.xlsx')
df
# Out:
#      C-18 POPULATION BY BILINGUALISM, TRILINGUALISM, AGE AND SEX Unnamed: 1  \
# 0                                                 State            District
# 1                                                  code                code
# 2                                                   NaN                 NaN
# 3                                                     1                   2
# 4                                                   NaN                 NaN
# ...                                                 ...                 ...
# 1080                                                 35                  00
# 1081                                                 35                  00
# 1082                                                 35                  00
# 1083                                                 35                  00
# 1084                                                 35                  00
#
#                      Unnamed: 2 Unnamed: 3      Unnamed: 4  \
# 0                     Area Name     Total/       Age-group
# 1                           NaN     Rural/             NaN
# 2                           NaN      Urban             NaN
# 3                             3          4               5
# 4                           NaN        NaN             NaN
# ...                         ...        ...             ...
# 1080  ANDAMAN & NICOBAR ISLANDS      Urban           25-29
# 1081  ANDAMAN & NICOBAR ISLANDS      Urban           30-49
# 1082  ANDAMAN & NICOBAR ISLANDS      Urban           50-69
# 1083  ANDAMAN & NICOBAR ISLANDS      Urban             70+
# 1084  ANDAMAN & NICOBAR ISLANDS      Urban  Age not stated
#
#                            Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0     Number speaking second language        NaN        NaN
# 1                                 NaN        NaN        NaN
# 2                             Persons      Males    Females
# 3                                   6          7          8
# 4                                 NaN        NaN        NaN
# ...                               ...        ...        ...
# 1080                            13065       7012       6053
# 1081                            38406      21301      17105
# 1082                            12899       7903       4996
# 1083                             1644       1016        628
# 1084                              134         70         64
#
#                           Unnamed: 8 Unnamed: 9 Unnamed: 10
# 0     Number speaking third language        NaN         NaN
# 1                                NaN        NaN         NaN
# 2                            Persons      Males     Females
# 3                                  9         10          11
# 4                                NaN        NaN         NaN
# ...                              ...        ...         ...
# 1080                            4364       2355        2009
# 1081                           13320       7824        5496
# 1082                            4177       2842        1335
# 1083                             432        305         127
# 1084                              38         19          19
#
# [1085 rows x 11 columns]

# %%
df.head(10)
# Out:
#   C-18 POPULATION BY BILINGUALISM, TRILINGUALISM, AGE AND SEX Unnamed: 1  \
# 0                                              State            District
# 1                                               code                code
# 2                                                NaN                 NaN
# 3                                                  1                   2
# 4                                                NaN                 NaN
# 5                                                 00                  00
# 6                                                 00                  00
# 7                                                 00                  00
# 8                                                 00                  00
# 9                                                 00                  00
#
#   Unnamed: 2 Unnamed: 3 Unnamed: 4                       Unnamed: 5  \
# 0  Area Name     Total/  Age-group  Number speaking second language
# 1        NaN     Rural/        NaN                              NaN
# 2        NaN      Urban        NaN                          Persons
# 3          3          4          5                                6
# 4        NaN        NaN        NaN                              NaN
# 5      INDIA      Total      Total                        314988770
# 6      INDIA      Total        5-9                         15649192
# 7      INDIA      Total      10-14                         34488492
# 8      INDIA      Total      15-19                         42424599
# 9      INDIA      Total      20-24                         41344406
#
#   Unnamed: 6 Unnamed: 7                      Unnamed: 8 Unnamed: 9 Unnamed: 10
# 0        NaN        NaN  Number speaking third language        NaN         NaN
# 1        NaN        NaN                             NaN        NaN         NaN
# 2      Males    Females                         Persons      Males     Females
# 3          7          8                               9         10          11
# 4        NaN        NaN                             NaN        NaN         NaN
# 5  176696383  138292387                        86009580   50536832    35472748
# 6    8166843    7482349                         1844108     978151      865957
# 7   18133423   16355069                         7254335    3831131     3423204
# 8   22750908   19673691                        12626717    6792766     5833951
# 9   22386694   18957712                        12834334    7067614     5766720

# %%
df2 = df.iloc[5:,:]
df2.head(10)
# Out:
#    C-18 POPULATION BY BILINGUALISM, TRILINGUALISM, AGE AND SEX Unnamed: 1  \
# 5                                                  00                  00
# 6                                                  00                  00
# 7                                                  00                  00
# 8                                                  00                  00
# 9                                                  00                  00
# 10                                                 00                  00
# 11                                                 00                  00
# 12                                                 00                  00
# 13                                                 00                  00
# 14                                                 00                  00
#
#    Unnamed: 2 Unnamed: 3      Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 5       INDIA      Total           Total  314988770  176696383  138292387
# 6       INDIA      Total             5-9   15649192    8166843    7482349
# 7       INDIA      Total           10-14   34488492   18133423   16355069
# 8       INDIA      Total           15-19   42424599   22750908   19673691
# 9       INDIA      Total           20-24   41344406   22386694   18957712
# 10      INDIA      Total           25-29   35924045   19695033   16229012
# 11      INDIA      Total           30-49   96443870   55866320   40577550
# 12      INDIA      Total           50-69   39729782   24306735   15423047
# 13      INDIA      Total             70+    7962347    4813671    3148676
# 14      INDIA      Total  Age not stated    1022037     576756     445281
#
#    Unnamed: 8 Unnamed: 9 Unnamed: 10
# 5    86009580   50536832    35472748
# 6     1844108     978151      865957
# 7     7254335    3831131     3423204
# 8    12626717    6792766     5833951
# 9    12834334    7067614     5766720
# 10   10857171    6144045     4713126
# 11   27466884   16824473    10642411
# 12   10916361    7385967     3530394
# 13    1954539    1362695      591844
# 14     255131     149990      105141

# %%
# Renaming Columns appropriately
df2.columns = ['State','District','Area','Region','Age_Group','Sec_Lang_Tot','Sec_Lang_M','Sec_Lang_F','Third_Lang_Tot','Third_Lang_M','Third_Lang_F']
df2
# Out:
#      State District                       Area Region       Age_Group  \
# 5       00       00                      INDIA  Total           Total
# 6       00       00                      INDIA  Total             5-9
# 7       00       00                      INDIA  Total           10-14
# 8       00       00                      INDIA  Total           15-19
# 9       00       00                      INDIA  Total           20-24
# ...    ...      ...                        ...    ...             ...
# 1080    35       00  ANDAMAN & NICOBAR ISLANDS  Urban           25-29
# 1081    35       00  ANDAMAN & NICOBAR ISLANDS  Urban           30-49
# 1082    35       00  ANDAMAN & NICOBAR ISLANDS  Urban           50-69
# 1083    35       00  ANDAMAN & NICOBAR ISLANDS  Urban             70+
# 1084    35       00  ANDAMAN & NICOBAR ISLANDS  Urban  Age not stated
#
#      Sec_Lang_Tot Sec_Lang_M Sec_Lang_F Third_Lang_Tot Third_Lang_M  \
# 5       314988770  176696383  138292387       86009580     50536832
# 6        15649192    8166843    7482349        1844108       978151
# 7        34488492   18133423   16355069        7254335      3831131
# 8        42424599   22750908   19673691       12626717      6792766
# 9        41344406   22386694   18957712       12834334      7067614
# ...           ...        ...        ...            ...          ...
# 1080        13065       7012       6053           4364         2355
# 1081        38406      21301      17105          13320         7824
# 1082        12899       7903       4996           4177         2842
# 1083         1644       1016        628            432          305
# 1084          134         70         64             38           19
#
#      Third_Lang_F
# 5        35472748
# 6          865957
# 7         3423204
# 8         5833951
# 9         5766720
# ...           ...
# 1080         2009
# 1081         5496
# 1082         1335
# 1083          127
# 1084           19
#
# [1080 rows x 11 columns]

# %%
df2.reset_index(drop = True, inplace = True)
df2
# Out:
#      State District                       Area Region       Age_Group  \
# 0       00       00                      INDIA  Total           Total
# 1       00       00                      INDIA  Total             5-9
# 2       00       00                      INDIA  Total           10-14
# 3       00       00                      INDIA  Total           15-19
# 4       00       00                      INDIA  Total           20-24
# ...    ...      ...                        ...    ...             ...
# 1075    35       00  ANDAMAN & NICOBAR ISLANDS  Urban           25-29
# 1076    35       00  ANDAMAN & NICOBAR ISLANDS  Urban           30-49
# 1077    35       00  ANDAMAN & NICOBAR ISLANDS  Urban           50-69
# 1078    35       00  ANDAMAN & NICOBAR ISLANDS  Urban             70+
# 1079    35       00  ANDAMAN & NICOBAR ISLANDS  Urban  Age not stated
#
#      Sec_Lang_Tot Sec_Lang_M Sec_Lang_F Third_Lang_Tot Third_Lang_M  \
# 0       314988770  176696383  138292387       86009580     50536832
# 1        15649192    8166843    7482349        1844108       978151
# 2        34488492   18133423   16355069        7254335      3831131
# 3        42424599   22750908   19673691       12626717      6792766
# 4        41344406   22386694   18957712       12834334      7067614
# ...           ...        ...        ...            ...          ...
# 1075        13065       7012       6053           4364         2355
# 1076        38406      21301      17105          13320         7824
# 1077        12899       7903       4996           4177         2842
# 1078         1644       1016        628            432          305
# 1079          134         70         64             38           19
#
#      Third_Lang_F
# 0        35472748
# 1          865957
# 2         3423204
# 3         5833951
# 4         5766720
# ...           ...
# 1075         2009
# 1076         5496
# 1077         1335
# 1078          127
# 1079           19
#
# [1080 rows x 11 columns]

# %%
# Dropping unnecessary columns
df2 = df2.drop(['District'], axis= 1 )
df2
# Out:
#      State                       Area Region       Age_Group Sec_Lang_Tot  \
# 0       00                      INDIA  Total           Total    314988770
# 1       00                      INDIA  Total             5-9     15649192
# 2       00                      INDIA  Total           10-14     34488492
# 3       00                      INDIA  Total           15-19     42424599
# 4       00                      INDIA  Total           20-24     41344406
# ...    ...                        ...    ...             ...          ...
# 1075    35  ANDAMAN & NICOBAR ISLANDS  Urban           25-29        13065
# 1076    35  ANDAMAN & NICOBAR ISLANDS  Urban           30-49        38406
# 1077    35  ANDAMAN & NICOBAR ISLANDS  Urban           50-69        12899
# 1078    35  ANDAMAN & NICOBAR ISLANDS  Urban             70+         1644
# 1079    35  ANDAMAN & NICOBAR ISLANDS  Urban  Age not stated          134
#
#      Sec_Lang_M Sec_Lang_F Third_Lang_Tot Third_Lang_M Third_Lang_F
# 0     176696383  138292387       86009580     50536832     35472748
# 1       8166843    7482349        1844108       978151       865957
# 2      18133423   16355069        7254335      3831131      3423204
# 3      22750908   19673691       12626717      6792766      5833951
# 4      22386694   18957712       12834334      7067614      5766720
# ...         ...        ...            ...          ...          ...
# 1075       7012       6053           4364         2355         2009
# 1076      21301      17105          13320         7824         5496
# 1077       7903       4996           4177         2842         1335
# 1078       1016        628            432          305          127
# 1079         70         64             38           19           19
#
# [1080 rows x 10 columns]

# %%
# Changing the data type of numerical attributes
for i in range(4,10):
    df2.iloc[:,i] = pd.to_numeric(df2.iloc[:,i])

# %%
df2[(df2['Area'] == 'INDIA') & (df2['Region'] == 'Total')]
# Out:
#   State   Area Region       Age_Group  Sec_Lang_Tot  Sec_Lang_M  Sec_Lang_F  \
# 0    00  INDIA  Total           Total     314988770   176696383   138292387
# 1    00  INDIA  Total             5-9      15649192     8166843     7482349
# 2    00  INDIA  Total           10-14      34488492    18133423    16355069
# 3    00  INDIA  Total           15-19      42424599    22750908    19673691
# 4    00  INDIA  Total           20-24      41344406    22386694    18957712
# 5    00  INDIA  Total           25-29      35924045    19695033    16229012
# 6    00  INDIA  Total           30-49      96443870    55866320    40577550
# 7    00  INDIA  Total           50-69      39729782    24306735    15423047
# 8    00  INDIA  Total             70+       7962347     4813671     3148676
# 9    00  INDIA  Total  Age not stated       1022037      576756      445281
#
#    Third_Lang_Tot  Third_Lang_M  Third_Lang_F
# 0        86009580      50536832      35472748
# 1         1844108        978151        865957
# 2         7254335       3831131       3423204
# 3        12626717       6792766       5833951
# 4        12834334       7067614       5766720
# 5        10857171       6144045       4713126
# 6        27466884      16824473      10642411
# 7        10916361       7385967       3530394
# 8         1954539       1362695        591844
# 9          255131        149990        105141

# %%
df3 = pd.DataFrame()

# %%
# Creating a dataframe which contains total triligual speakers of each age group for every Area
for area in df2['Area'].unique():
    temp_df = df2[(df2['Area'].str.upper() == area.upper()) & (df2['Region'].str.upper() == 'TOTAL')].iloc[1:,:]
    temp_df.drop(['State','Region','Sec_Lang_Tot','Sec_Lang_M','Sec_Lang_F','Third_Lang_M','Third_Lang_F'], axis=1, inplace = True)
    df3 = pd.concat([df3, temp_df])
df3
# Out:
#                            Area       Age_Group  Third_Lang_Tot
# 1                         INDIA             5-9         1844108
# 2                         INDIA           10-14         7254335
# 3                         INDIA           15-19        12626717
# 4                         INDIA           20-24        12834334
# 5                         INDIA           25-29        10857171
# ...                         ...             ...             ...
# 1055  ANDAMAN & NICOBAR ISLANDS           25-29            9716
# 1056  ANDAMAN & NICOBAR ISLANDS           30-49           27080
# 1057  ANDAMAN & NICOBAR ISLANDS           50-69            7803
# 1058  ANDAMAN & NICOBAR ISLANDS             70+             771
# 1059  ANDAMAN & NICOBAR ISLANDS  Age not stated              64
#
# [324 rows x 3 columns]

# %%
# Reading C-14 to find the age group wise population in each state
pop_df = pd.read_excel('DDW-0000C-14.xls')
pop_df.head(10)
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0      Table      State     Distt.  Area Name
# 1       Name       Code       Code        NaN
# 2        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN
# 5        NaN        NaN        NaN        NaN
# 6      C4114         00        000      India
# 7      C4114         00        000      India
# 8      C4114         00        000      India
# 9      C4114         00        000      India
#
#   C-14 POPULATION IN FIVE YEAR AGE-GROUP BY RESIDENCE AND SEX   Unnamed: 5  \
# 0                                          Age-group                Total
# 1                                                NaN                   NaN
# 2                                                NaN               Persons
# 3                                                  1                     2
# 4                                                NaN                   NaN
# 5                                                NaN                   NaN
# 6                                           All ages            1210854977
# 7                                                0-4             112806778
# 8                                                5-9             126928126
# 9                                              10-14             132709212
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0        NaN        NaN      Rural        NaN         NaN       Urban
# 1        NaN        NaN        NaN        NaN         NaN         NaN
# 2      Males    Females    Persons      Males     Females     Persons
# 3          3          4          5          6           7           8
# 4        NaN        NaN        NaN        NaN         NaN         NaN
# 5        NaN        NaN        NaN        NaN         NaN         NaN
# 6  623270258  587584719  833748852  427781058   405967794   377106125
# 7   58632074   54174704   82986660   43036377    39950283    29820118
# 8   66300466   60627660   93807612   48825259    44982353    33120514
# 9   69418835   63290377   96804494   50488158    46316336    35904718
#
#   Unnamed: 12 Unnamed: 13
# 0         NaN         NaN
# 1         NaN         NaN
# 2       Males     Females
# 3           9          10
# 4         NaN         NaN
# 5         NaN         NaN
# 6   195489200   181616925
# 7    15595697    14224421
# 8    17475207    15645307
# 9    18930677    16974041

# %%
pop_df.columns = ['Table_Name','State_Code','District_Code','Area','Age_Group','Total_Person','Total_Male','Total_Female','Rural_Person',
                'Rural_Male','Rural_Female','Urban_Person','Urban_Male','Urban_Female']
pop_df.head(10)
# Out:
#   Table_Name State_Code District_Code       Area  Age_Group Total_Person  \
# 0      Table      State        Distt.  Area Name  Age-group       Total
# 1       Name       Code          Code        NaN        NaN          NaN
# 2        NaN        NaN           NaN        NaN        NaN      Persons
# 3        NaN        NaN           NaN        NaN          1            2
# 4        NaN        NaN           NaN        NaN        NaN          NaN
# 5        NaN        NaN           NaN        NaN        NaN          NaN
# 6      C4114         00           000      India   All ages   1210854977
# 7      C4114         00           000      India        0-4    112806778
# 8      C4114         00           000      India        5-9    126928126
# 9      C4114         00           000      India      10-14    132709212
#
#   Total_Male Total_Female Rural_Person Rural_Male Rural_Female Urban_Person  \
# 0        NaN          NaN        Rural        NaN          NaN        Urban
# 1        NaN          NaN          NaN        NaN          NaN          NaN
# 2      Males      Females      Persons      Males      Females      Persons
# 3          3            4            5          6            7            8
# 4        NaN          NaN          NaN        NaN          NaN          NaN
# 5        NaN          NaN          NaN        NaN          NaN          NaN
# 6  623270258    587584719    833748852  427781058    405967794    377106125
# 7   58632074     54174704     82986660   43036377     39950283     29820118
# 8   66300466     60627660     93807612   48825259     44982353     33120514
# 9   69418835     63290377     96804494   50488158     46316336     35904718
#
#   Urban_Male Urban_Female
# 0        NaN          NaN
# 1        NaN          NaN
# 2      Males      Females
# 3          9           10
# 4        NaN          NaN
# 5        NaN          NaN
# 6  195489200    181616925
# 7   15595697     14224421
# 8   17475207     15645307
# 9   18930677     16974041

# %%
pop_df = pop_df.iloc[6:,:]
pop_df
# Out:
#     Table_Name State_Code District_Code  \
# 6        C4114         00           000
# 7        C4114         00           000
# 8        C4114         00           000
# 9        C4114         00           000
# 10       C4114         00           000
# ..         ...        ...           ...
# 685      C4114         35           000
# 686      C4114         35           000
# 687      C4114         35           000
# 688      C4114         35           000
# 689      C4114         35           000
#
#                                        Area       Age_Group Total_Person  \
# 6                                     India        All ages   1210854977
# 7                                     India             0-4    112806778
# 8                                     India             5-9    126928126
# 9                                     India           10-14    132709212
# 10                                    India           15-19    120526449
# ..                                      ...             ...          ...
# 685  State - ANDAMAN & NICOBAR ISLANDS (35)           65-69         6226
# 686  State - ANDAMAN & NICOBAR ISLANDS (35)           70-74         4098
# 687  State - ANDAMAN & NICOBAR ISLANDS (35)           75-79         2251
# 688  State - ANDAMAN & NICOBAR ISLANDS (35)             80+         2473
# 689  State - ANDAMAN & NICOBAR ISLANDS (35)  Age not stated          368
#
#     Total_Male Total_Female Rural_Person Rural_Male Rural_Female Urban_Person  \
# 6    623270258    587584719    833748852  427781058    405967794    377106125
# 7     58632074     54174704     82986660   43036377     39950283     29820118
# 8     66300466     60627660     93807612   48825259     44982353     33120514
# 9     69418835     63290377     96804494   50488158     46316336     35904718
# 10    63982396     56544053     83902472   44570557     39331915     36623977
# ..         ...          ...          ...        ...          ...          ...
# 685       3430         2796         4469       2477         1992         1757
# 686       2378         1720         2905       1687         1218         1193
# 687       1295          956         1606        952          654          645
# 688       1279         1194         1857        992          865          616
# 689        195          173          180        101           79          188
#
#     Urban_Male Urban_Female
# 6    195489200    181616925
# 7     15595697     14224421
# 8     17475207     15645307
# 9     18930677     16974041
# 10    19411839     17212138
# ..         ...          ...
# 685        953          804
# 686        691          502
# 687        343          302
# 688        287          329
# 689         94           94
#
# [684 rows x 14 columns]

# %%
pop_df.reset_index(inplace=True,drop=True)
pop_df
# Out:
#     Table_Name State_Code District_Code  \
# 0        C4114         00           000
# 1        C4114         00           000
# 2        C4114         00           000
# 3        C4114         00           000
# 4        C4114         00           000
# ..         ...        ...           ...
# 679      C4114         35           000
# 680      C4114         35           000
# 681      C4114         35           000
# 682      C4114         35           000
# 683      C4114         35           000
#
#                                        Area       Age_Group Total_Person  \
# 0                                     India        All ages   1210854977
# 1                                     India             0-4    112806778
# 2                                     India             5-9    126928126
# 3                                     India           10-14    132709212
# 4                                     India           15-19    120526449
# ..                                      ...             ...          ...
# 679  State - ANDAMAN & NICOBAR ISLANDS (35)           65-69         6226
# 680  State - ANDAMAN & NICOBAR ISLANDS (35)           70-74         4098
# 681  State - ANDAMAN & NICOBAR ISLANDS (35)           75-79         2251
# 682  State - ANDAMAN & NICOBAR ISLANDS (35)             80+         2473
# 683  State - ANDAMAN & NICOBAR ISLANDS (35)  Age not stated          368
#
#     Total_Male Total_Female Rural_Person Rural_Male Rural_Female Urban_Person  \
# 0    623270258    587584719    833748852  427781058    405967794    377106125
# 1     58632074     54174704     82986660   43036377     39950283     29820118
# 2     66300466     60627660     93807612   48825259     44982353     33120514
# 3     69418835     63290377     96804494   50488158     46316336     35904718
# 4     63982396     56544053     83902472   44570557     39331915     36623977
# ..         ...          ...          ...        ...          ...          ...
# 679       3430         2796         4469       2477         1992         1757
# 680       2378         1720         2905       1687         1218         1193
# 681       1295          956         1606        952          654          645
# 682       1279         1194         1857        992          865          616
# 683        195          173          180        101           79          188
#
#     Urban_Male Urban_Female
# 0    195489200    181616925
# 1     15595697     14224421
# 2     17475207     15645307
# 3     18930677     16974041
# 4     19411839     17212138
# ..         ...          ...
# 679        953          804
# 680        691          502
# 681        343          302
# 682        287          329
# 683         94           94
#
# [684 rows x 14 columns]

# %%
pop_df.columns
# Out:
# Index(['Table_Name', 'State_Code', 'District_Code', 'Area', 'Age_Group',
#        'Total_Person', 'Total_Male', 'Total_Female', 'Rural_Person',
#        'Rural_Male', 'Rural_Female', 'Urban_Person', 'Urban_Male',
#        'Urban_Female'],
#       dtype='object')

# %%
# Dropping unnessecary columns
pop_df = pop_df.drop(['Table_Name', 'State_Code', 'District_Code','Total_Male', 'Total_Female', 'Rural_Person',
       'Rural_Male', 'Rural_Female', 'Urban_Person', 'Urban_Male',
       'Urban_Female'],axis=1)
pop_df
# Out:
#                                        Area       Age_Group Total_Person
# 0                                     India        All ages   1210854977
# 1                                     India             0-4    112806778
# 2                                     India             5-9    126928126
# 3                                     India           10-14    132709212
# 4                                     India           15-19    120526449
# ..                                      ...             ...          ...
# 679  State - ANDAMAN & NICOBAR ISLANDS (35)           65-69         6226
# 680  State - ANDAMAN & NICOBAR ISLANDS (35)           70-74         4098
# 681  State - ANDAMAN & NICOBAR ISLANDS (35)           75-79         2251
# 682  State - ANDAMAN & NICOBAR ISLANDS (35)             80+         2473
# 683  State - ANDAMAN & NICOBAR ISLANDS (35)  Age not stated          368
#
# [684 rows x 3 columns]

# %%
# Adding population column
df3['Population'] = np.nan

df3
# Out:
#                            Area       Age_Group  Third_Lang_Tot  Population
# 1                         INDIA             5-9         1844108         NaN
# 2                         INDIA           10-14         7254335         NaN
# 3                         INDIA           15-19        12626717         NaN
# 4                         INDIA           20-24        12834334         NaN
# 5                         INDIA           25-29        10857171         NaN
# ...                         ...             ...             ...         ...
# 1055  ANDAMAN & NICOBAR ISLANDS           25-29            9716         NaN
# 1056  ANDAMAN & NICOBAR ISLANDS           30-49           27080         NaN
# 1057  ANDAMAN & NICOBAR ISLANDS           50-69            7803         NaN
# 1058  ANDAMAN & NICOBAR ISLANDS             70+             771         NaN
# 1059  ANDAMAN & NICOBAR ISLANDS  Age not stated              64         NaN
#
# [324 rows x 4 columns]

# %%
df3.reset_index(drop=True,inplace=True)
df3
# Out:
#                           Area       Age_Group  Third_Lang_Tot  Population
# 0                        INDIA             5-9         1844108         NaN
# 1                        INDIA           10-14         7254335         NaN
# 2                        INDIA           15-19        12626717         NaN
# 3                        INDIA           20-24        12834334         NaN
# 4                        INDIA           25-29        10857171         NaN
# ..                         ...             ...             ...         ...
# 319  ANDAMAN & NICOBAR ISLANDS           25-29            9716         NaN
# 320  ANDAMAN & NICOBAR ISLANDS           30-49           27080         NaN
# 321  ANDAMAN & NICOBAR ISLANDS           50-69            7803         NaN
# 322  ANDAMAN & NICOBAR ISLANDS             70+             771         NaN
# 323  ANDAMAN & NICOBAR ISLANDS  Age not stated              64         NaN
#
# [324 rows x 4 columns]

# %%
pop_df
# Out:
#                                        Area       Age_Group Total_Person
# 0                                     India        All ages   1210854977
# 1                                     India             0-4    112806778
# 2                                     India             5-9    126928126
# 3                                     India           10-14    132709212
# 4                                     India           15-19    120526449
# ..                                      ...             ...          ...
# 679  State - ANDAMAN & NICOBAR ISLANDS (35)           65-69         6226
# 680  State - ANDAMAN & NICOBAR ISLANDS (35)           70-74         4098
# 681  State - ANDAMAN & NICOBAR ISLANDS (35)           75-79         2251
# 682  State - ANDAMAN & NICOBAR ISLANDS (35)             80+         2473
# 683  State - ANDAMAN & NICOBAR ISLANDS (35)  Age not stated          368
#
# [684 rows x 3 columns]

# %%
pop_df[[True if 'ANDAMAN & NICOBAR ISLANDS' in i else False for i in pop_df['Area']]]
# Out:
#                                        Area       Age_Group Total_Person
# 665  State - ANDAMAN & NICOBAR ISLANDS (35)        All ages       380581
# 666  State - ANDAMAN & NICOBAR ISLANDS (35)             0-4        28754
# 667  State - ANDAMAN & NICOBAR ISLANDS (35)             5-9        30454
# 668  State - ANDAMAN & NICOBAR ISLANDS (35)           10-14        33467
# 669  State - ANDAMAN & NICOBAR ISLANDS (35)           15-19        33026
# 670  State - ANDAMAN & NICOBAR ISLANDS (35)           20-24        37115
# 671  State - ANDAMAN & NICOBAR ISLANDS (35)           25-29        41722
# 672  State - ANDAMAN & NICOBAR ISLANDS (35)           30-34        35723
# 673  State - ANDAMAN & NICOBAR ISLANDS (35)           35-39        32842
# 674  State - ANDAMAN & NICOBAR ISLANDS (35)           40-44        26735
# 675  State - ANDAMAN & NICOBAR ISLANDS (35)           45-49        23861
# 676  State - ANDAMAN & NICOBAR ISLANDS (35)           50-54        17296
# 677  State - ANDAMAN & NICOBAR ISLANDS (35)           55-59        13794
# 678  State - ANDAMAN & NICOBAR ISLANDS (35)           60-64        10376
# 679  State - ANDAMAN & NICOBAR ISLANDS (35)           65-69         6226
# 680  State - ANDAMAN & NICOBAR ISLANDS (35)           70-74         4098
# 681  State - ANDAMAN & NICOBAR ISLANDS (35)           75-79         2251
# 682  State - ANDAMAN & NICOBAR ISLANDS (35)             80+         2473
# 683  State - ANDAMAN & NICOBAR ISLANDS (35)  Age not stated          368

# %%
pop_df2 = pop_df.copy()
pop_df2
# Out:
#                                        Area       Age_Group Total_Person
# 0                                     India        All ages   1210854977
# 1                                     India             0-4    112806778
# 2                                     India             5-9    126928126
# 3                                     India           10-14    132709212
# 4                                     India           15-19    120526449
# ..                                      ...             ...          ...
# 679  State - ANDAMAN & NICOBAR ISLANDS (35)           65-69         6226
# 680  State - ANDAMAN & NICOBAR ISLANDS (35)           70-74         4098
# 681  State - ANDAMAN & NICOBAR ISLANDS (35)           75-79         2251
# 682  State - ANDAMAN & NICOBAR ISLANDS (35)             80+         2473
# 683  State - ANDAMAN & NICOBAR ISLANDS (35)  Age not stated          368
#
# [684 rows x 3 columns]

# %%
pop_df2['Total_Person'] = pd.to_numeric(pop_df2['Total_Person'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 684 entries, 0 to 683
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area          684 non-null    object
#  1   Age_Group     684 non-null    object
#  2   Total_Person  684 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 16.2+ KB

# %%
df3.head(20)
# Out:
#                 Area       Age_Group  Third_Lang_Tot  Population
# 0              INDIA             5-9         1844108         NaN
# 1              INDIA           10-14         7254335         NaN
# 2              INDIA           15-19        12626717         NaN
# 3              INDIA           20-24        12834334         NaN
# 4              INDIA           25-29        10857171         NaN
# 5              INDIA           30-49        27466884         NaN
# 6              INDIA           50-69        10916361         NaN
# 7              INDIA             70+         1954539         NaN
# 8              INDIA  Age not stated          255131         NaN
# 9    JAMMU & KASHMIR             5-9           73589         NaN
# 10   JAMMU & KASHMIR           10-14          222586         NaN
# 11   JAMMU & KASHMIR           15-19          339152         NaN
# 12   JAMMU & KASHMIR           20-24          343400         NaN
# 13   JAMMU & KASHMIR           25-29          271949         NaN
# 14   JAMMU & KASHMIR           30-49          607745         NaN
# 15   JAMMU & KASHMIR           50-69          202306         NaN
# 16   JAMMU & KASHMIR             70+           33910         NaN
# 17   JAMMU & KASHMIR  Age not stated            1583         NaN
# 18  HIMACHAL PRADESH             5-9            6545         NaN
# 19  HIMACHAL PRADESH           10-14           29483         NaN

# %%
pop_df2.head(20)
# Out:
#                             Area       Age_Group  Total_Person
# 0                          India        All ages    1210854977
# 1                          India             0-4     112806778
# 2                          India             5-9     126928126
# 3                          India           10-14     132709212
# 4                          India           15-19     120526449
# 5                          India           20-24     111424222
# 6                          India           25-29     101413965
# 7                          India           30-34      88594951
# 8                          India           35-39      85140684
# 9                          India           40-44      72438112
# 10                         India           45-49      62318327
# 11                         India           50-54      49069254
# 12                         India           55-59      39146055
# 13                         India           60-64      37663707
# 14                         India           65-69      26454983
# 15                         India           70-74      19208842
# 16                         India           75-79       9232503
# 17                         India             80+      11289005
# 18                         India  Age not stated       4489802
# 19  State - JAMMU & KASHMIR (01)        All ages      12541302

# %% [markdown]
# #### As df3 has age groups which are merge of age groups present in pop_df2 (for example: df3 contains 30-49 while pop_df2 contains 30-34,35-39,40-44,45-49) so to find 30-49 population we have to sum the populations of 30-34,35-39,40-44,45-49 age groups in pop_df2

# %%
i = 0
while i < pop_df.shape[0]:
    if '30' in pop_df2.loc[i,'Age_Group']:
        age_group_pop_sum = pop_df2.loc[i,'Total_Person']
        j = i + 1
        while not '49' in pop_df2.loc[j,'Age_Group']:
            age_group_pop_sum += pop_df2.loc[j,'Total_Person']
            pop_df2.drop(j,axis=0,inplace=True)
            j += 1
        age_group_pop_sum += pop_df2.loc[j,'Total_Person']
        pop_df2.drop(j,axis=0,inplace=True)
        pop_df2.loc[i,'Total_Person'] = age_group_pop_sum
        pop_df2.loc[i,'Age_Group'] = '30-49'
        i = j
        i += 1
        continue
        
    if '50' in pop_df2.loc[i,'Age_Group']:
        age_group_pop_sum = pop_df2.loc[i,'Total_Person']
        j = i + 1
        while not '69' in pop_df2.loc[j,'Age_Group']:
            age_group_pop_sum += pop_df2.loc[j,'Total_Person']
            pop_df2.drop(j,axis=0,inplace=True)
            j += 1
        age_group_pop_sum += pop_df2.loc[j,'Total_Person']
        pop_df2.drop(j,axis=0,inplace=True)
        pop_df2.loc[i,'Total_Person'] = age_group_pop_sum
        pop_df2.loc[i,'Age_Group'] = '50-69'
        i = j
        i += 1
        continue
        
    if '70' in pop_df2.loc[i,'Age_Group']:
        age_group_pop_sum = pop_df2.loc[i,'Total_Person']
        j = i + 1
        while not '80' in pop_df2.loc[j,'Age_Group']:
            age_group_pop_sum += pop_df2.loc[j,'Total_Person']
            pop_df2.drop(j,axis=0,inplace=True)
            j += 1
        age_group_pop_sum += pop_df2.loc[j,'Total_Person']
        pop_df2.drop(j,axis=0,inplace=True)
        pop_df2.loc[i,'Total_Person'] = age_group_pop_sum
        pop_df2.loc[i,'Age_Group'] = '70+'
        i = j
        i += 1
        continue
    
    i += 1

# %%
pop_df2.head(20)
# Out:
#                             Area       Age_Group  Total_Person
# 0                          India        All ages    1210854977
# 1                          India             0-4     112806778
# 2                          India             5-9     126928126
# 3                          India           10-14     132709212
# 4                          India           15-19     120526449
# 5                          India           20-24     111424222
# 6                          India           25-29     101413965
# 7                          India           30-49     308492074
# 11                         India           50-69     152333999
# 15                         India             70+      39730350
# 18                         India  Age not stated       4489802
# 19  State - JAMMU & KASHMIR (01)        All ages      12541302
# 20  State - JAMMU & KASHMIR (01)             0-4       1414884
# 21  State - JAMMU & KASHMIR (01)             5-9       1411973
# 22  State - JAMMU & KASHMIR (01)           10-14       1413853
# 23  State - JAMMU & KASHMIR (01)           15-19       1237462
# 24  State - JAMMU & KASHMIR (01)           20-24       1160913
# 25  State - JAMMU & KASHMIR (01)           25-29       1086122
# 26  State - JAMMU & KASHMIR (01)           30-49       3069723
# 30  State - JAMMU & KASHMIR (01)           50-69       1335288

# %%
pop_df2.reset_index(inplace=True,drop=True)
pop_df2
# Out:
#                                        Area       Age_Group  Total_Person
# 0                                     India        All ages    1210854977
# 1                                     India             0-4     112806778
# 2                                     India             5-9     126928126
# 3                                     India           10-14     132709212
# 4                                     India           15-19     120526449
# ..                                      ...             ...           ...
# 391  State - ANDAMAN & NICOBAR ISLANDS (35)           25-29         41722
# 392  State - ANDAMAN & NICOBAR ISLANDS (35)           30-49        119161
# 393  State - ANDAMAN & NICOBAR ISLANDS (35)           50-69         47692
# 394  State - ANDAMAN & NICOBAR ISLANDS (35)             70+          8822
# 395  State - ANDAMAN & NICOBAR ISLANDS (35)  Age not stated           368
#
# [396 rows x 3 columns]

# %%
# Finding the population of each age group from pop_df2 and adding it to df3
for i in df3.index:
    temp_df = pop_df2[[True if df3.iloc[i,0].upper() in area.upper() else False for area in pop_df2['Area']]]
    df3.iloc[i,3] = int(temp_df[temp_df['Age_Group'] == df3.iloc[i,1]].iloc[0]['Total_Person'])
df3
# Out:
#                           Area       Age_Group  Third_Lang_Tot   Population
# 0                        INDIA             5-9         1844108  126928126.0
# 1                        INDIA           10-14         7254335  132709212.0
# 2                        INDIA           15-19        12626717  120526449.0
# 3                        INDIA           20-24        12834334  111424222.0
# 4                        INDIA           25-29        10857171  101413965.0
# ..                         ...             ...             ...          ...
# 319  ANDAMAN & NICOBAR ISLANDS           25-29            9716      41722.0
# 320  ANDAMAN & NICOBAR ISLANDS           30-49           27080     119161.0
# 321  ANDAMAN & NICOBAR ISLANDS           50-69            7803      47692.0
# 322  ANDAMAN & NICOBAR ISLANDS             70+             771       8822.0
# 323  ANDAMAN & NICOBAR ISLANDS  Age not stated              64        368.0
#
# [324 rows x 4 columns]

# %%
df3.head(20)
# Out:
#                 Area       Age_Group  Third_Lang_Tot   Population
# 0              INDIA             5-9         1844108  126928126.0
# 1              INDIA           10-14         7254335  132709212.0
# 2              INDIA           15-19        12626717  120526449.0
# 3              INDIA           20-24        12834334  111424222.0
# 4              INDIA           25-29        10857171  101413965.0
# 5              INDIA           30-49        27466884  308492074.0
# 6              INDIA           50-69        10916361  152333999.0
# 7              INDIA             70+         1954539   39730350.0
# 8              INDIA  Age not stated          255131    4489802.0
# 9    JAMMU & KASHMIR             5-9           73589    1411973.0
# 10   JAMMU & KASHMIR           10-14          222586    1413853.0
# 11   JAMMU & KASHMIR           15-19          339152    1237462.0
# 12   JAMMU & KASHMIR           20-24          343400    1160913.0
# 13   JAMMU & KASHMIR           25-29          271949    1086122.0
# 14   JAMMU & KASHMIR           30-49          607745    3069723.0
# 15   JAMMU & KASHMIR           50-69          202306    1335288.0
# 16   JAMMU & KASHMIR             70+           33910     395965.0
# 17   JAMMU & KASHMIR  Age not stated            1583      15119.0
# 18  HIMACHAL PRADESH             5-9            6545     591177.0
# 19  HIMACHAL PRADESH           10-14           29483     639224.0

# %%
# Finding the percentage of people trilingual in each age group of every state
df3['Trilingual (%)'] = (df3['Third_Lang_Tot'] / df3['Population']) * 100
df3
# Out:
#                           Area       Age_Group  Third_Lang_Tot   Population  \
# 0                        INDIA             5-9         1844108  126928126.0
# 1                        INDIA           10-14         7254335  132709212.0
# 2                        INDIA           15-19        12626717  120526449.0
# 3                        INDIA           20-24        12834334  111424222.0
# 4                        INDIA           25-29        10857171  101413965.0
# ..                         ...             ...             ...          ...
# 319  ANDAMAN & NICOBAR ISLANDS           25-29            9716      41722.0
# 320  ANDAMAN & NICOBAR ISLANDS           30-49           27080     119161.0
# 321  ANDAMAN & NICOBAR ISLANDS           50-69            7803      47692.0
# 322  ANDAMAN & NICOBAR ISLANDS             70+             771       8822.0
# 323  ANDAMAN & NICOBAR ISLANDS  Age not stated              64        368.0
#
#      Trilingual (%)
# 0          1.452876
# 1          5.466339
# 2         10.476304
# 3         11.518442
# 4         10.705795
# ..              ...
# 319       23.287474
# 320       22.725556
# 321       16.361235
# 322        8.739515
# 323       17.391304
#
# [324 rows x 5 columns]

# %%
df4 = df3.drop(['Third_Lang_Tot','Population'],axis=1)
df4
# Out:
#                           Area       Age_Group  Trilingual (%)
# 0                        INDIA             5-9        1.452876
# 1                        INDIA           10-14        5.466339
# 2                        INDIA           15-19       10.476304
# 3                        INDIA           20-24       11.518442
# 4                        INDIA           25-29       10.705795
# ..                         ...             ...             ...
# 319  ANDAMAN & NICOBAR ISLANDS           25-29       23.287474
# 320  ANDAMAN & NICOBAR ISLANDS           30-49       22.725556
# 321  ANDAMAN & NICOBAR ISLANDS           50-69       16.361235
# 322  ANDAMAN & NICOBAR ISLANDS             70+        8.739515
# 323  ANDAMAN & NICOBAR ISLANDS  Age not stated       17.391304
#
# [324 rows x 3 columns]

# %%
# Finding the age group for each state which has maximum percentage of trilingual people
idx = df4.groupby(['Area'])['Trilingual (%)'].transform(max) == df4['Trilingual (%)']
df5 = df4[idx]
df5
# Out:
#                           Area Age_Group  Trilingual (%)
# 3                        INDIA     20-24       11.518442
# 12             JAMMU & KASHMIR     20-24       29.580167
# 21            HIMACHAL PRADESH     20-24        8.206521
# 29                      PUNJAB     15-19       45.763949
# 42                  CHANDIGARH     50-69       42.774903
# 48                 UTTARAKHAND     20-24        3.094835
# 56                     HARYANA     15-19        7.318620
# 70                NCT OF DELHI       70+       14.999231
# 74                   RAJASTHAN     15-19        2.884065
# 84               UTTAR PRADESH     20-24        2.443396
# 92                       BIHAR     15-19        2.918430
# 101                     SIKKIM     15-19       45.798288
# 110          ARUNACHAL PRADESH     15-19       47.589249
# 120                   NAGALAND     20-24       40.339983
# 130                    MANIPUR     25-29       31.663321
# 140                    MIZORAM     30-49        7.420447
# 147                    TRIPURA     20-24        8.211385
# 158                  MEGHALAYA     30-49       14.862512
# 165                      ASSAM     20-24       21.065613
# 177                WEST BENGAL     50-69        4.457691
# 183                  JHARKHAND     20-24        7.375031
# 191                     ODISHA     15-19       22.309814
# 202               CHHATTISGARH     25-29        2.296116
# 209             MADHYA PRADESH     15-19        2.963277
# 218                    GUJARAT     15-19       23.986559
# 230                DAMAN & DIU     30-49       18.178144
# 236       DADRA & NAGAR HAVELI     15-19       33.829749
# 246                MAHARASHTRA     20-24       27.068174
# 254             ANDHRA PRADESH     15-19       12.981033
# 264                  KARNATAKA     20-24       17.577031
# 272                        GOA     15-19       68.088694
# 282                LAKSHADWEEP     20-24       25.990736
# 291                     KERALA     20-24       16.945888
# 300                 TAMIL NADU     20-24        4.589020
# 309                 PUDUCHERRY     20-24        7.852489
# 317  ANDAMAN & NICOBAR ISLANDS     15-19       28.747048

# %%
df5.reset_index(drop=True, inplace=True)

# %%
df5
# Out:
#                          Area Age_Group  Trilingual (%)
# 0                       INDIA     20-24       11.518442
# 1             JAMMU & KASHMIR     20-24       29.580167
# 2            HIMACHAL PRADESH     20-24        8.206521
# 3                      PUNJAB     15-19       45.763949
# 4                  CHANDIGARH     50-69       42.774903
# 5                 UTTARAKHAND     20-24        3.094835
# 6                     HARYANA     15-19        7.318620
# 7                NCT OF DELHI       70+       14.999231
# 8                   RAJASTHAN     15-19        2.884065
# 9               UTTAR PRADESH     20-24        2.443396
# 10                      BIHAR     15-19        2.918430
# 11                     SIKKIM     15-19       45.798288
# 12          ARUNACHAL PRADESH     15-19       47.589249
# 13                   NAGALAND     20-24       40.339983
# 14                    MANIPUR     25-29       31.663321
# 15                    MIZORAM     30-49        7.420447
# 16                    TRIPURA     20-24        8.211385
# 17                  MEGHALAYA     30-49       14.862512
# 18                      ASSAM     20-24       21.065613
# 19                WEST BENGAL     50-69        4.457691
# 20                  JHARKHAND     20-24        7.375031
# 21                     ODISHA     15-19       22.309814
# 22               CHHATTISGARH     25-29        2.296116
# 23             MADHYA PRADESH     15-19        2.963277
# 24                    GUJARAT     15-19       23.986559
# 25                DAMAN & DIU     30-49       18.178144
# 26       DADRA & NAGAR HAVELI     15-19       33.829749
# 27                MAHARASHTRA     20-24       27.068174
# 28             ANDHRA PRADESH     15-19       12.981033
# 29                  KARNATAKA     20-24       17.577031
# 30                        GOA     15-19       68.088694
# 31                LAKSHADWEEP     20-24       25.990736
# 32                     KERALA     20-24       16.945888
# 33                 TAMIL NADU     20-24        4.589020
# 34                 PUDUCHERRY     20-24        7.852489
# 35  ANDAMAN & NICOBAR ISLANDS     15-19       28.747048

# %%
df5.columns = ['state/ut', 'age-group', 'percentage']
df5
# Out:
#                      state/ut age-group  percentage
# 0                       INDIA     20-24   11.518442
# 1             JAMMU & KASHMIR     20-24   29.580167
# 2            HIMACHAL PRADESH     20-24    8.206521
# 3                      PUNJAB     15-19   45.763949
# 4                  CHANDIGARH     50-69   42.774903
# 5                 UTTARAKHAND     20-24    3.094835
# 6                     HARYANA     15-19    7.318620
# 7                NCT OF DELHI       70+   14.999231
# 8                   RAJASTHAN     15-19    2.884065
# 9               UTTAR PRADESH     20-24    2.443396
# 10                      BIHAR     15-19    2.918430
# 11                     SIKKIM     15-19   45.798288
# 12          ARUNACHAL PRADESH     15-19   47.589249
# 13                   NAGALAND     20-24   40.339983
# 14                    MANIPUR     25-29   31.663321
# 15                    MIZORAM     30-49    7.420447
# 16                    TRIPURA     20-24    8.211385
# 17                  MEGHALAYA     30-49   14.862512
# 18                      ASSAM     20-24   21.065613
# 19                WEST BENGAL     50-69    4.457691
# 20                  JHARKHAND     20-24    7.375031
# 21                     ODISHA     15-19   22.309814
# 22               CHHATTISGARH     25-29    2.296116
# 23             MADHYA PRADESH     15-19    2.963277
# 24                    GUJARAT     15-19   23.986559
# 25                DAMAN & DIU     30-49   18.178144
# 26       DADRA & NAGAR HAVELI     15-19   33.829749
# 27                MAHARASHTRA     20-24   27.068174
# 28             ANDHRA PRADESH     15-19   12.981033
# 29                  KARNATAKA     20-24   17.577031
# 30                        GOA     15-19   68.088694
# 31                LAKSHADWEEP     20-24   25.990736
# 32                     KERALA     20-24   16.945888
# 33                 TAMIL NADU     20-24    4.589020
# 34                 PUDUCHERRY     20-24    7.852489
# 35  ANDAMAN & NICOBAR ISLANDS     15-19   28.747048

# %%
# Saving the results in age-india.csv inside Results directory
df5.to_csv('Results/age-india.csv',index=None)
